# %%
import dotenv
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# C:\Users\noeln\AppData\Local\Temp\ipykernel_12784\1474760240.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   embeddings = HuggingFaceEmbeddings(

# %%
REVIEWS_CHROMA_PATH = "C:\\Users\\noeln\\Desktop\\llm\\20260106_llm_chatbot\\langchain_intro\\chromadb\\chroma_data\\"

dotenv.load_dotenv()

reviews_vector_db = Chroma(
    persist_directory=REVIEWS_CHROMA_PATH,
    embedding_function=embeddings,
)
# Out:
# C:\Users\noeln\AppData\Local\Temp\ipykernel_12784\2826038672.py:5: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 0.4. An updated version of the class exists in the langchain-chroma package and should be used instead. To use it run `pip install -U langchain-chroma` and import as `from langchain_chroma import Chroma`.
#   reviews_vector_db = Chroma(

# %%
question = """Has anyone complained about communication with the hospital staff?"""
relevant_docs = reviews_vector_db.similarity_search(question, k=3)

# %%
relevant_docs
# Out:
# [Document(metadata={'row': 293, 'source': 'The hospital staff was caring and attentive. The facilities were clean, and the medical care was excellent. However, the noise level in the ward was higher than expected, affecting my rest.'}, page_content='review_id: 495\nvisit_id: 3777\nreview: The hospital staff was caring and attentive. The facilities were clean, and the medical care was excellent. However, the noise level in the ward was higher than expected, affecting my rest.\nphysician_name: Michael Watson\nhospital_name: Vaughn PLC\npatient_name: Mrs. Kelly Berry DVM'),
#  Document(metadata={'row': 995, 'source': 'The hospital provided excellent care, and the staff was attentive to my needs. However, the noise level in the ward was a bit disruptive.'}, page_content='review_id: 813\nvisit_id: 1702\nreview: The hospital provided excellent care, and the staff was attentive to my needs. However, the noise level in the ward was a bit disruptive.\nphysician_name: David Carter\nhospital_name: Jordan Inc\npatient_name: Michael Herrera'),
#  Document(metadata={'row': 381, 'source': "The hospital's medical team was competent, but the noise level in the ward was disruptive, affecting my ability to rest."}, page_content="review_id: 574\nvisit_id: 7162\nreview: The hospital's medical team was competent, but the noise level in the ward was disruptive, affecting my ability to rest.\nphysician_name: Teresa Frost\nhospital_name: Walton LLC\npatient_name: Kelsey Mills")]

# %%
relevant_docs[0].page_content
# Out:
# 'review_id: 495\nvisit_id: 3777\nreview: The hospital staff was caring and attentive. The facilities were clean, and the medical care was excellent. However, the noise level in the ward was higher than expected, affecting my rest.\nphysician_name: Michael Watson\nhospital_name: Vaughn PLC\npatient_name: Mrs. Kelly Berry DVM'

# %%
relevant_docs[1].page_content
# Out:
# 'review_id: 813\nvisit_id: 1702\nreview: The hospital provided excellent care, and the staff was attentive to my needs. However, the noise level in the ward was a bit disruptive.\nphysician_name: David Carter\nhospital_name: Jordan Inc\npatient_name: Michael Herrera'

# %%
relevant_docs[2].page_content
# Out:
# "review_id: 574\nvisit_id: 7162\nreview: The hospital's medical team was competent, but the noise level in the ward was disruptive, affecting my ability to rest.\nphysician_name: Teresa Frost\nhospital_name: Walton LLC\npatient_name: Kelsey Mills"
